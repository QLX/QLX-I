# %% [markdown]
# # [Table Of Contents](../index.ipynb)
# ### The Art of Data Storytelling

# %% [markdown]
# # The Global Superstore Case
#
# This page contains student files for the case "Modern Retail Analytics: Data Visualization Using Tableau." It includes three detailed tutorials that can be used by instructors in the classroom to introduce students to Tableau and Data Storytelling in the context of retail strategy and operations (using the [Global Superstore dataset](files/Global.Superstore.xlsx) that is made available with Tableau).

# %%
import pandas as pd

df = pd.read_excel('../files/Global.Superstore.xlsx')
southeast_asia = ['Cambodia', 'Indonesia', 'Malaysia', 'Myanmar (Burma)',
                  'Philippines', 'Singapore', 'Thailand', 'Vietnam']
grouped = df[df.Country.isin(southeast_asia)][['Category', 'Country', 'Profit']].sort_values('Profit')
grouped = grouped[:100].groupby(['Category', 'Country'])

mydict = {"Category": [], "Country" : [], "Profit": []}
for key, item in grouped:
    # print(item)
    a_group = grouped.get_group(key)
    mydict["Category"].append(a_group["Category"].iloc[0])
    mydict["Country"].append(a_group["Country"].iloc[0])
    mydict["Profit"].append(a_group.sum(axis=0, skipna=True)["Profit"])
    
data = pd.DataFrame(mydict).sort_values('Profit')
print(data)
# Out:
#            Category          Country      Profit
# 0         Furniture        Indonesia -10494.5229
# 2         Furniture      Philippines  -5018.7000
# 3         Furniture         Thailand  -4820.2251
# 9        Technology      Philippines  -3785.3820
# 4         Furniture          Vietnam  -2970.1839
# 6   Office Supplies      Philippines  -2968.6425
# 11       Technology          Vietnam  -2945.2590
# 1         Furniture  Myanmar (Burma)  -1763.3916
# 8        Technology        Indonesia  -1594.5852
# 5   Office Supplies        Indonesia   -989.4879
# 10       Technology         Thailand   -869.8290
# 7   Office Supplies         Thailand   -594.1581

# %%
df
# Out:
#        Row ID         Order ID Order Date            Ship Date  \
# 0       32298   CA-2012-124891 2014-07-31  2014-07-31 00:00:00
# 1       26341    IN-2013-77878 2015-02-05  2015-02-07 00:00:00
# 2       25330    IN-2013-71249 2015-10-17  2015-10-18 00:00:00
# 3       13524  ES-2013-1579342 2015-01-28  2015-01-30 00:00:00
# 4       47221     SG-2013-4320 2015-11-05  2015-11-06 00:00:00
# ...       ...              ...        ...                  ...
# 51285   29002    IN-2014-62366 2016-06-19  2016-06-19 00:00:00
# 51286   35398   US-2014-102288 2016-06-20  2016-06-24 00:00:00
# 51287   40470   US-2013-155768 2015-12-02  2015-12-02 00:00:00
# 51288    9596   MX-2012-140767 2014-02-18  2014-02-22 00:00:00
# 51289    6147   MX-2012-134460 2014-05-22  2014-05-26 00:00:00
#
#             Ship Mode Customer ID     Customer Name      Segment  \
# 0            Same Day    RH-19495       Rick Hansen     Consumer
# 1        Second Class    JR-16210     Justin Ritter    Corporate
# 2         First Class    CR-12730      Craig Reiter     Consumer
# 3         First Class    KM-16375  Katherine Murray  Home Office
# 4            Same Day     RH-9495       Rick Hansen     Consumer
# ...               ...         ...               ...          ...
# 51285        Same Day    KE-16420   Katrina Edelman    Corporate
# 51286  Standard Class    ZC-21910  Zuschuss Carroll     Consumer
# 51287        Same Day    LB-16795    Laurel Beltran  Home Office
# 51288  Standard Class    RB-19795        Ross Baird  Home Office
# 51289    Second Class    MC-18100     Mick Crebagga     Consumer
#
#                 City            State  ...        Product ID         Category  \
# 0      New York City         New York  ...   TEC-AC-10003033       Technology
# 1         Wollongong  New South Wales  ...   FUR-CH-10003950        Furniture
# 2           Brisbane       Queensland  ...   TEC-PH-10004664       Technology
# 3             Berlin           Berlin  ...   TEC-PH-10004583       Technology
# 4              Dakar            Dakar  ...  TEC-SHA-10000501       Technology
# ...              ...              ...  ...               ...              ...
# 51285           Kure        Hiroshima  ...   OFF-FA-10000746  Office Supplies
# 51286        Houston            Texas  ...   OFF-AP-10002906  Office Supplies
# 51287         Oxnard       California  ...   OFF-EN-10001219  Office Supplies
# 51288       Valinhos        São Paulo  ...   OFF-BI-10000806  Office Supplies
# 51289       Tipitapa          Managua  ...   OFF-PA-10004155  Office Supplies
#
#       Sub-Category                                       Product Name  \
# 0      Accessories  Plantronics CS510 - Over-the-Head monaural Wir...
# 1           Chairs          Novimex Executive Leather Armchair, Black
# 2           Phones                  Nokia Smart Phone, with Caller ID
# 3           Phones                     Motorola Smart Phone, Cordless
# 4          Copiers                     Sharp Wireless Fax, High-Speed
# ...            ...                                                ...
# 51285    Fasteners                      Advantus Thumb Tacks, 12 Pack
# 51286   Appliances  Hoover Replacement Belt for Commercial Guardsm...
# 51287    Envelopes       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes
# 51288      Binders                            Acco Index Tab, Economy
# 51289        Paper            Eaton Computer Printout Paper, 8.5 x 11
#
#           Sales Quantity Discount    Profit  Shipping Cost  Order Priority
# 0      2309.650        7      0.0  762.1845        933.570        Critical
# 1      3709.395        9      0.1 -288.7650        923.630        Critical
# 2      5175.171        9      0.1  919.9710        915.490          Medium
# 3      2892.510        5      0.1  -96.5400        910.160          Medium
# 4      2832.960        8      0.0  311.5200        903.040        Critical
# ...         ...      ...      ...       ...            ...             ...
# 51285    65.100        5      0.0    4.5000          0.010          Medium
# 51286     0.444        1      0.8   -1.1100          0.010          Medium
# 51287    22.920        3      0.0   11.2308          0.010            High
# 51288    13.440        2      0.0    2.4000          0.003          Medium
# 51289    61.380        3      0.0    1.8000          0.002            High
#
# [51290 rows x 24 columns]

# %% [markdown]
# ## Assignments

# %%
import random

def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]

#input names of students
n = ['Abagail', 'Adelina', 'Alexandra', 'Allan', 'Dan', 'Divya', 'Elisbelka', 'Irene', 'Jaclyn', 'Jorge', 'Jose', 'Kianna', 'Maggie', 'Maheen',
                  'Mallory', 'Marvell', 'Naquasha', 'Patrick', 'Preston', 'Reed', 'Ricardo', 'Rita', 'Rupesh', 'Ryan', 'Shanice', 'Smita', 'Sonika', 'Evert', 'Yasmine']

random.shuffle(n)

list(chunks(n, 5))
# Out:
# [['Kianna', 'Patrick', 'Jaclyn', 'Smita', 'Preston'],
#  ['Shanice', 'Alexandra', 'Evert', 'Adelina', 'Rita'],
#  ['Mallory', 'Elisbelka', 'Jorge', 'Divya', 'Ryan'],
#  ['Maheen', 'Abagail', 'Reed', 'Maggie', 'Naquasha'],
#  ['Jose', 'Ricardo', 'Irene', 'Allan', 'Dan'],
#  ['Yasmine', 'Sonika', 'Marvell', 'Rupesh']]

# %% [markdown]
# [Assignment One](assignment_1/index.ipynb) | [Assignment Two](assignment_2/index.ipynb) | [Assignment Three](assignment_3/index.ipynb) | [Assignment Four](assignment_4/index.ipynb) | [Assignment Five](assignment_5/index.ipynb) | [Assignment Six](assignment_6/index.ipynb)
